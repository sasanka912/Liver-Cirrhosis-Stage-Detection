# %% [markdown]
# **Read dataset**

# %% [markdown]
# # New Section

# %%
import pandas as pd

file_name = "liver_cirrhosis.csv"

# Load dataset as dataframe (csv file)
dataset = pd.read_csv(file_name)
#print(dataset)

# %%
dataset
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %% [markdown]
# **Dataset Analysis**

# %%
# column of the dataset
dataset.columns
# Out:
# Index(['N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites', 'Hepatomegaly',
#        'Spiders', 'Edema', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',
#        'Stage'],
#       dtype='object')

# %%
# Shape of the dataset
dataset.shape
# Out:
# (25000, 19)

# %%
#Show first 5 rows of dataset
dataset.head()
# Out:
#    N_Days Status     Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0    2221      C  Placebo  18499   F       N            Y       N     N
# 1    1230      C  Placebo  19724   M       Y            N       Y     N
# 2    4184      C  Placebo  11839   F       N            N       N     N
# 3    2090      D  Placebo  16467   F       N            N       N     N
# 4    2105      D  Placebo  21699   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        0.5        149.0     4.04   227.0     598.0   52.70           57.0
# 1        0.5        219.0     3.93    22.0     663.0   45.00           75.0
# 2        0.5        320.0     3.54    51.0    1243.0  122.45           80.0
# 3        0.7        255.0     3.74    23.0    1024.0   77.50           58.0
# 4        1.9        486.0     3.54    74.0    1052.0  108.50          109.0
#
#    Platelets  Prothrombin  Stage
# 0      256.0          9.9      1
# ...

# %%
#shows 5 random rows from dataset
dataset.sample(5)
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 3118     2403      C  D-penicillamine  25594   M       N            N       N
# 20623    3092     CL          Placebo  12433   F       N            Y       N
# 3599      549      D  D-penicillamine  16736   F       N            Y       Y
# 3700     1770      C  D-penicillamine  25006   F       N            Y       Y
# 13408     974      D          Placebo  21904   F       N            Y       N
#
#       Edema  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# 3118      S        0.4   369.510563     3.81   97.648387  1982.655769
# 20623     N        1.1   464.000000     4.20   38.000000  1644.000000
# 3599      Y       17.2   222.000000     3.23  209.000000  1975.000000
# 3700      N        1.1   246.000000     3.35  116.000000   824.000000
# 13408     N       11.0   674.000000     3.55  358.000000  2412.000000
#
#              SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
#returns description of the data in the DataFrame
dataset.describe()
# Out:
#              N_Days           Age     Bilirubin   Cholesterol       Albumin  \
# count  25000.000000  25000.000000  25000.000000  25000.000000  25000.000000
# mean    1887.117040  18495.877080      3.402644    372.331471      3.486578
# std     1091.690918   3737.596616      4.707491    193.668452      0.380488
# min       41.000000   9598.000000      0.300000    120.000000      1.960000
# 25%     1080.000000  15694.000000      0.800000    275.000000      3.290000
# 50%     1680.000000  18499.000000      1.300000    369.510563      3.510000
# 75%     2576.000000  20955.000000      3.400000    369.510563      3.750000
# max     4795.000000  28650.000000     28.000000   1775.000000      4.640000
#
#              Copper      Alk_Phos          SGOT  Tryglicerides     Platelets  \
# count  25000.000000  25000.000000  25000.000000   25000.000000  25000.000000
# mean     100.184663   1995.675597    123.166345     123.822548    256.007337
# ...

# %%
#Categorical feature
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         25000 non-null  int64
#  1   Status         25000 non-null  object
#  2   Drug           25000 non-null  object
#  3   Age            25000 non-null  int64
#  4   Sex            25000 non-null  object
#  5   Ascites        25000 non-null  object
#  6   Hepatomegaly   25000 non-null  object
#  7   Spiders        25000 non-null  object
#  8   Edema          25000 non-null  object
#  9   Bilirubin      25000 non-null  float64
#  10  Cholesterol    25000 non-null  float64
#  11  Albumin        25000 non-null  float64
#  12  Copper         25000 non-null  float64
#  13  Alk_Phos       25000 non-null  float64
#  14  SGOT           25000 non-null  float64
#  15  Tryglicerides  25000 non-null  float64
#  16  Platelets      25000 non-null  float64
# ...

# %%
#checking if there is any null
dataset.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %% [markdown]
# **Dataset Visualization**

# %%
import seaborn as sn
import matplotlib.pyplot as plt
# #variable_to_plot = 'Sex'
# columns = dataset.columns
# for i in range(0,len(columns)-1):
#  variable_to_plot = columns[i]
#  plt.figure(figsize=(8, 6))
#  plt.hist(dataset[variable_to_plot], edgecolor='black')
#  plt.title(f'Histogram of {variable_to_plot}')
#  plt.xlabel(variable_to_plot)
#  plt.ylabel('Frequency')
#  plt.show()
plt.figure(figsize = (30,20))
loop = dataset[["Bilirubin","Copper",'Prothrombin',"Tryglicerides","SGOT"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(3,2,i)
    sn.regplot(x = dataset[c],y = dataset["Stage"],scatter=False, color='orchid',)

# %%
#Scatter plot
# import seaborn as sns
# column = dataset.columns
# for i in range(1,len(column)-1):
#   feature1 = column[i]
#   feature2 = 'Stage'
#   plt.figure(figsize=(8, 6))
#   sns.scatterplot(data=dataset, x=feature1, y=feature2, marker='o', color='blue')
#   plt.title(f'Scatter Plot of {feature1} vs Stage')
#   plt.xlabel(f'{feature1}')
#   plt.ylabel('Stage')
#   plt.show()

plt.figure(figsize = (30,20))
loop = dataset[["Albumin","Platelets","Cholesterol"]]
i = 0
for c in loop:
    i +=1
    plt.subplot(2,2,i)
    sn.regplot(x = dataset[c],y = dataset["Stage"],scatter=False, color='orchid')

# %%
plt.figure(figsize=(20,10))


plt.subplot(2,2,1)
sn.barplot(x=dataset['Stage'],y = dataset["Bilirubin"],hue=dataset['Sex'], palette='ocean', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Bilirubin')


plt.subplot(2,2,2)
sn.barplot(x=dataset['Stage'],y = dataset["Copper"],hue=dataset['Sex'], palette='ocean_r', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Copper')


plt.subplot(2,2,3)
sn.barplot(x=dataset['Stage'],y = dataset["Tryglicerides"],hue=dataset['Sex'], palette='copper_r', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with Tryglicerides')

plt.subplot(2,2,4)
sn.barplot(x=dataset['Stage'],y = dataset["SGOT"],hue=dataset['Sex'], palette='crest', alpha=0.9)
sn.despine(top=True, right=True, bottom=True, left=True)
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False)
plt.xlabel('')
plt.title('positive correlation of gender ("Female") with SGOT')
# Out:
# Text(0.5, 1.0, 'positive correlation of gender ("Female") with SGOT')

# %% [markdown]
# **Dataset Pre-processing**

# %%
#Cleaning null value
arr = dataset.select_dtypes(include = (['int64', 'float64'])).columns
#print(arr)
for c in arr:
    dataset[c].fillna(dataset[c].median(), inplace=True)
#dataset
arr.isna()
col = dataset.select_dtypes(include=('object')).columns
#print(col)
for c in col:
    dataset[c].fillna(dataset[c].mode().values[0], inplace=True)

dataset.select_dtypes(include=('object')).isna().sum()
# Out:
# Status          0
# Drug            0
# Sex             0
# Ascites         0
# Hepatomegaly    0
# Spiders         0
# Edema           0
# dtype: int64

# %%
dataset
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
# from sklearn.preprocessing import LabelEncoder

# # Set up the LabelEncoder object
# enc = LabelEncoder()

# # Apply the encoding to the "Accessible" column
# dataset['Status_enc'] = enc.fit_transform(dataset['Status'])

# # Compare the two columns
# print(dataset[['Status', 'Status_enc']].head())

# %%
# dataset["Status"].unique()

# %%
# dataset['Status_enc'] = dataset['Status'].map({'C':0,'D': 1,'CL':2})

# %%
# dataset.shape

# %%
# dataset[["Status", "Status_enc"]]

# %%
# dataset = dataset.drop(["Status"], axis=1)

# %%
# dataset.shape

# %%
# dataset.head()

# %%
dataset["Sex"].replace("M",0,inplace = True)
dataset["Sex"].replace("F",1,inplace = True)
dataset["Stage"].replace(4,"x",inplace = True)
dataset["Stage"].replace(1,0,inplace = True)
dataset["Stage"].replace(2,0,inplace = True)
dataset["Stage"].replace(3,0,inplace = True)
dataset["Stage"].replace("x",1,inplace = True)
dataset["Hepatomegaly"].replace("Y",1,inplace = True)
dataset["Hepatomegaly"].replace("N",0,inplace = True)
dataset["Ascites"].replace("Y",1,inplace = True)
dataset["Ascites"].replace("N",0,inplace = True)
dataset["Edema"].replace("Y",1,inplace = True)
dataset["Edema"].replace("N",0,inplace = True)
dataset["Edema"].replace("S",0,inplace = True)
dataset["Status"].replace("CL",0,inplace=True)
dataset["Status"].replace("C",1,inplace=True)
dataset["Status"].replace("D",0,inplace=True)
dataset["Drug"].replace("D-penicillamine",1,inplace = True)
dataset["Drug"].replace("Placebo",0,inplace = True)
dataset["Spiders"].replace("Y",1,inplace = True)
dataset["Spiders"].replace("N",0,inplace = True)

dataset
# Out:
#        N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0        2221       1     0  18499    1        0             1        0
# 1        1230       1     0  19724    0        1             0        1
# 2        4184       1     0  11839    1        0             0        0
# 3        2090       0     0  16467    1        0             0        0
# 4        2105       0     0  21699    1        0             1        0
# ...       ...     ...   ...    ...  ...      ...           ...      ...
# 24995    3584       0     1  23612    1        0             0        0
# 24996    3584       0     1  23612    1        0             0        0
# 24997     971       0     1  16736    1        0             1        1
# 24998    3707       1     1  16990    1        0             1        0
# 24999    3707       1     1  16990    1        0             1        0
#
#        Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler


list_of_features = ["N_Days", "Age", "Bilirubin", "Cholesterol", "Albumin", "Copper","Alk_Phos","SGOT","Tryglicerides","Platelets","Prothrombin"]

scaler = MinMaxScaler()

dataset[list_of_features] = scaler.fit_transform(dataset[list_of_features])

# %%
dataset.head()
# Out:
#      N_Days  Status  Drug       Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0  0.458561       1     0  0.467195    1        0             1        0
# 1  0.250105       1     0  0.531493    0        1             0        1
# 2  0.871477       1     0  0.117625    1        0             0        0
# 3  0.431005       0     0  0.360540    1        0             0        0
# 4  0.434161       0     0  0.635156    1        0             1        0
#
#    Edema  Bilirubin  Cholesterol   Albumin    Copper  Alk_Phos      SGOT  \
# 0      0   0.007220     0.017523  0.776119  0.381849  0.022765  0.061151
# 1      0   0.007220     0.059819  0.735075  0.030822  0.027554  0.043282
# 2      0   0.007220     0.120846  0.589552  0.080479  0.070285  0.223022
# 3      0   0.014440     0.081571  0.664179  0.032534  0.054150  0.118705
# 4      0   0.057762     0.221148  0.589552  0.119863  0.056213  0.190647
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
x_data = dataset[['N_Days', 'Status', 'Drug',
       'Age', 'Sex', 'Ascites', 'Hepatomegaly',
       'Spiders', 'Edema','Bilirubin','Cholesterol','Albumin','Copper','Alk_Phos','SGOT','Tryglicerides','Platelets','Prothrombin']]
y_data = dataset[["Stage"]]

# %%
x_data
# Out:
#          N_Days  Status  Drug       Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0      0.458561       1     0  0.467195    1        0             1        0
# 1      0.250105       1     0  0.531493    0        1             0        1
# 2      0.871477       1     0  0.117625    1        0             0        0
# 3      0.431005       0     0  0.360540    1        0             0        0
# 4      0.434161       0     0  0.635156    1        0             1        0
# ...         ...     ...   ...       ...  ...      ...           ...      ...
# 24995  0.745267       0     1  0.735566    1        0             0        0
# 24996  0.745267       0     1  0.735566    1        0             0        0
# 24997  0.195625       0     1  0.374659    1        0             1        1
# 24998  0.771140       1     1  0.387991    1        0             1        0
# 24999  0.771140       1     1  0.387991    1        0             1        0
#
# ...

# %%
y_data
# Out:
#        Stage
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 24995      0
# 24996      0
# 24997      0
# 24998      0
# 24999      0
#
# [25000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data,
                                                    test_size = 0.2,
                                                    random_state = 1,
                                                    stratify = y_data)
print("Training data",X_test)
# Out:
# Training data          N_Days  Status  Drug       Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 10740  0.265250       1     0  0.182396    1        0             1        0
# 19445  0.269247       1     0  0.097837    1        0             0        0
# 3412   0.653976       1     1  0.319966    1        0             0        0
# 2044   0.274716       0     1  0.837077    0        0             1        0
# 5842   0.018721       0     0  0.569179    1        1             1        1
# ...         ...     ...   ...       ...  ...      ...           ...      ...
# 21592  0.243164       0     0  0.301438    1        1             0        1
# 24011  0.472655       0     1  0.432815    1        0             1        0
# 14454  0.270930       1     0  0.531493    1        1             0        1
# 5541   0.199411       1     0  0.167227    1        1             0        1
# 10672  0.297434       1     0  0.146966    1        0             1        0
#
# ...

# %%
X_train.shape, X_test.shape
# Out:
# ((20000, 18), (5000, 18))

# %%
y_train.shape, y_test.shape
# Out:
# ((20000, 1), (5000, 1))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Load and clean data
df = pd.read_csv("liver_cirrhosis.csv").dropna()

# Encode categorical features
for col in df.select_dtypes(include='object').columns:
    df[col] = LabelEncoder().fit_transform(df[col])

# Define features and target
X = df.drop(columns=['Stage'])
y = df['Stage']

# ✅ Stratified split ensures all classes are in both sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# %%
dataset.shape
# Out:
# (25000, 19)

# %%
X_train.shape
# Out:
# (17500, 18)

# %%
from sklearn.metrics import accuracy_score

lr=accuracy_score(y_test, y_pred)
print(lr)
# Out:
# 0.5197333333333334

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
#confusion matrix for LOGISTIC REGRESSION

#y_pred = model.predict(x_test)
cm = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
import numpy as np

X_train = np.asarray(X_train, dtype=np.float64)
X_test = np.asarray(X_test, dtype=np.float64)

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=10)
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)

# %%
X_train.shape
# Out:
# (17500, 18)

# %%
kn=accuracy_score(y_test, y_pred)
print(kn)
# Out:
# 0.78

# %%
cm2 = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm2,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
from sklearn.ensemble import RandomForestClassifier
model3 =  RandomForestClassifier(n_estimators = 100,max_depth = 12,random_state = 0)
model3.fit(X_train, y_train)
y_pred = model3.predict(X_test)

# %%
X_train.shape
# Out:
# (17500, 18)

# %%
rf=accuracy_score(y_test, y_pred)
print(rf)
# Out:
# 0.9328

# %%
cm3 = confusion_matrix(y_test,y_pred)


plt.figure(figsize = (8,6))
sn.heatmap(cm3,annot = True)
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(70.72222222222221, 0.5, 'Truth')

# %%
model_names = ['KNeighbors','Logistic Regression', 'Random Forest']
accuracy_scores = [kn,lr,rf]

plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracy_scores, color=['blue', 'green','red'])
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model Comparison - Accuracy Scores")
plt.ylim(0, 1.0)
plt.show()

# %%
import pandas as pd

# Model names and accuracy scores
model_names = ['K-Nearest Neighbors', 'Logistic Regression', 'Random Forest']
accuracy_scores = [kn, lr, rf]

# Create a DataFrame to display as a table
accuracy_df = pd.DataFrame({
    'Model': model_names,
    'Accuracy': [f"{score:.4f}" for score in accuracy_scores]
})

# Display the table
print("📊 Accuracy Comparison Table:")
print(accuracy_df.to_string(index=False))
# Out:
# 📊 Accuracy Comparison Table:
#               Model Accuracy
# K-Nearest Neighbors   0.7800
# Logistic Regression   0.5197
#       Random Forest   0.9328
